# %% [markdown]
# <a href="https://colab.research.google.com/github/aparna-2001/nifty50-stock-price-forecasting/blob/main/nifty50_daily_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
import os

# %%
ticker = "^NSEI"
df = yf.download(ticker, start="2000-01-01", interval="1d", auto_adjust=True)


if isinstance(df.columns, pd.MultiIndex):
    df.columns = df.columns.get_level_values(0)


df.index.name = "Date"
df = df[["Open", "High", "Low", "Close", "Volume"]]
df.dropna(inplace=True)

print(f"Shape       : {df.shape}")
print(f"Date range  : {df.index.min().date()} → {df.index.max().date()}")
print(f"Missing vals:\n{df.isnull().sum()}")
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Shape       : (4540, 5)
# Date range  : 2007-09-17 → 2026-03-20
# Missing vals:
# Price
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64
# Price              Open         High          Low        Close  Volume
# Date
# 2007-09-17  4518.450195  4549.049805  4482.850098  4494.649902       0
# 2007-09-18  4494.100098  4551.799805  4481.549805  4546.200195       0
# 2007-09-19  4550.250000  4739.000000  4550.250000  4732.350098       0
# 2007-09-20  4734.850098  4760.850098  4721.149902  4747.549805       0
# 2007-09-21  4752.950195  4855.700195  4733.700195  4837.549805       0

# %% [markdown]
# since the data is from 2007, we need to download and merge the data from 1999.
